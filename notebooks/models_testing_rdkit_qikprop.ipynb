# %% [markdown]
# ## Data split

# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from scripts.baseline_model import MoleculeModel
from scripts.utils import generate_descriptors
from collections import defaultdict
from tqdm.notebook import tqdm
import numpy as np

# %%
import pandas as pd

# %%
data_train_val = pd.read_csv('../data/split/data_train_val.csv')
data_test = pd.read_csv('../data/split/data_test.csv')

# %%
data_train_val
# Out:
#                                                 smiles  active
# 0                        CCN(CC)CC(=O)NC1=C(C=CC=C1C)C       1
# 1    C1=CC=C2C(=C1)C(=CC(=N2)C3=NC4=CC=CC=C4C(=C3)C...       1
# 2         CN(C)CCCN1C2=CC=CC=C2SC3=C1C=C(C=C3)C(F)(F)F       1
# 3    CC1C=CC=CC=CC=CC=CC=CC=CC(CC2C(C(CC(O2)(CC(CC(...       1
# 4             C[C@H](CN1C=NC2=C(N=CN=C21)N)OCP(=O)(O)O       0
# ..                                                 ...     ...
# 383           C1=CC(=CC=C1C2=COC3=CC(=CC(=C3C2=O)O)O)O       1
# 384  CC(=O)N(C)C1=C(C(=C(C(=C1I)C(=O)NCC(=O)NC2=C(C...       0
# 385  CCN1C=C(C(=O)C2=CC(=C(C(=C21)F)N3CCNC(C3)C)F)C...       0
# 386        C1=C(N=C(S1)N=C(N)N)CSCC/C(=N/S(=O)(=O)N)/N       0
# 387              CC(C1=CC(=C(C=C1)C2=CC=CC=C2)F)C(=O)O       1
#
# [388 rows x 2 columns]

# %%
data_test
# Out:
#                                                smiles  active
# 0   CC(=O)OCC1=C(N2[C@@H]([C@@H](C2=O)NC(=O)CCC[C@...       0
# 1                               C1CCC(CC1)(CC(=O)O)CN       0
# 2                CN(C)CCC(C1=CC=C(C=C1)Cl)C2=CC=CC=N2       1
# 3   CC1=C(C(C(=C(N1)C)C(=O)OC)C2=CC=CC=C2[N+](=O)[...       1
# 4                         C1=CC(=C(C=C1[C@H](CN)O)O)O       1
# ..                                                ...     ...
# 93  CC[C@H](C)C(=O)O[C@H]1C[C@H](C=C2[C@H]1[C@H]([...       1
# 94      C1CC1C#CC2(C3=C(C=CC(=C3)Cl)NC(=O)O2)C(F)(F)F       1
# 95                                 C1CC(CCC1CN)C(=O)O       0
# 96  CC(=O)N(CC(CO)O)C1=C(C(=C(C(=C1I)C(=O)NCC(CO)O...       0
# 97  CC(=O)S[C@@H]1CC2=CC(=O)CC[C@@]2([C@@H]3[C@@H]...       1
#
# [98 rows x 2 columns]

# %%
TARGET_COLUMN = 'active'

# %%
FP_SIZE = 512
FP_RADIUS = 2

# %%
data_train_val = generate_descriptors(data_train_val, fp_size=FP_SIZE, fp_radius=FP_RADIUS)
data_test = generate_descriptors(data_test, fp_size=FP_SIZE, fp_radius=FP_RADIUS)
# Out:
#   0%|          | 0/388 [00:00<?, ?it/s]
#   0%|          | 0/98 [00:00<?, ?it/s]

# %%
data_train_val
# Out:
#                                                 smiles  active  fp0  fp1  \
# 0                        CCN(CC)CC(=O)NC1=C(C=CC=C1C)C       1  0.0  0.0
# 2         CN(C)CCCN1C2=CC=CC=C2SC3=C1C=C(C=C3)C(F)(F)F       1  0.0  0.0
# 3    CC1C=CC=CC=CC=CC=CC=CC=CC(CC2C(C(CC(O2)(CC(CC(...       1  0.0  0.0
# 4             C[C@H](CN1C=NC2=C(N=CN=C21)N)OCP(=O)(O)O       0  0.0  0.0
# 5    CC1=C(C=CC=C1O)C(=O)N[C@@H](CSC2=CC=CC=C2)[C@@...       1  0.0  0.0
# ..                                                 ...     ...  ...  ...
# 383           C1=CC(=CC=C1C2=COC3=CC(=CC(=C3C2=O)O)O)O       1  0.0  1.0
# 384  CC(=O)N(C)C1=C(C(=C(C(=C1I)C(=O)NCC(=O)NC2=C(C...       0  0.0  1.0
# 385  CCN1C=C(C(=O)C2=CC(=C(C(=C21)F)N3CCNC(C3)C)F)C...       0  0.0  1.0
# 386        C1=C(N=C(S1)N=C(N)N)CSCC/C(=N/S(=O)(=O)N)/N       0  0.0  1.0
# 387              CC(C1=CC(=C(C=C1)C2=CC=CC=C2)F)C(=O)O       1  0.0  1.0
#
#      MaxEStateIndex  MinEStateIndex  MaxAbsEStateIndex  MinAbsEStateIndex  \
# 0         11.892319        0.061204          11.892319           0.061204
# 2         13.106724       -4.327413          13.106724           0.598296
# 3         12.613219       -2.325406          12.613219           0.107125
# 4         10.708321       -4.158240          10.708321           0.284758
# 5         13.460934       -0.886246          13.460934           0.012366
# ..              ...             ...                ...                ...
# 383       12.611767       -3.869125          12.611767           0.108750
# 384       12.381821       -0.407926          12.381821           0.007755
# 385       13.434808       -1.313589          13.434808           0.012637
# 386       15.192672       -1.421368          15.192672           0.069365
# 387       10.648671       -3.916263          10.648671           0.014378
#
#           qed     MolWt  ...  SAamideO      PSA  #NandO  RuleOfFive  \
# 0    0.848967   234.343  ...     0.000   33.679     3.0         0.0
# 2    0.741025   352.425  ...     0.000    8.655     2.0         1.0
# 3    0.173524   924.091  ...     0.000  310.079    18.0         3.0
# 4    0.650814   287.216  ...     0.000  136.649     9.0         0.0
# 5    0.326501   567.796  ...     3.696   96.920     7.0         1.0
# ..        ...       ...  ...       ...      ...     ...         ...
# 383  0.904699   322.386  ...     0.000   99.973     5.0         0.0
# 384  0.631833   270.240  ...     0.000  233.071    13.0         3.0
# 385  0.195023  1268.883  ...     0.000   96.645     6.0         0.0
# 386  0.882035   351.353  ...     0.000  190.934     9.0         1.0
# 387  0.286612   337.456  ...     0.000   48.639     2.0         0.0
#
#      RuleOfThree  #ringatoms  #in34  #in56  #noncon  #nonHatm
# 0            0.0         6.0    0.0    6.0      0.0      17.0
# 2            0.0        14.0    0.0   14.0      0.0      24.0
# 3            2.0        12.0    0.0   12.0     10.0      65.0
# 4            1.0         9.0    0.0    9.0      0.0      19.0
# 5            0.0        22.0    0.0   22.0      9.0      40.0
# ..           ...         ...    ...    ...      ...       ...
# 383          0.0        16.0    0.0   16.0      0.0      20.0
# 384          2.0        12.0    0.0   12.0      0.0      43.0
# 385          1.0        16.0    0.0   16.0      4.0      25.0
# 386          1.0         5.0    0.0    5.0      0.0      20.0
# 387          0.0        12.0    0.0   12.0      0.0      18.0
#
# [372 rows x 261 columns]

# %%
data_test
# Out:
#                                                smiles  active  fp0  fp1  \
# 0   CC(=O)OCC1=C(N2[C@@H]([C@@H](C2=O)NC(=O)CCC[C@...       0    0    1
# 1                               C1CCC(CC1)(CC(=O)O)CN       0    0    1
# 2                CN(C)CCC(C1=CC=C(C=C1)Cl)C2=CC=CC=N2       1    0    1
# 3   CC1=C(C(C(=C(N1)C)C(=O)OC)C2=CC=CC=C2[N+](=O)[...       1    0    1
# 4                         C1=CC(=C(C=C1[C@H](CN)O)O)O       1    0    1
# ..                                                ...     ...  ...  ...
# 93  CC[C@H](C)C(=O)O[C@H]1C[C@H](C=C2[C@H]1[C@H]([...       1    0    1
# 94      C1CC1C#CC2(C3=C(C=CC(=C3)Cl)NC(=O)O2)C(F)(F)F       1    0    1
# 95                                 C1CC(CCC1CN)C(=O)O       0    0    1
# 96  CC(=O)N(CC(CO)O)C1=C(C(=C(C(=C1I)C(=O)NCC(CO)O...       0    0    1
# 97  CC(=O)S[C@@H]1CC2=CC(=O)CC[C@@]2([C@@H]3[C@@H]...       1    0    1
#
#     MaxEStateIndex  MinEStateIndex  MaxAbsEStateIndex  MinAbsEStateIndex  \
# 0        12.396276       -1.311818          12.396276           0.001464
# 1        10.576064       -0.706157          10.576064           0.079282
# 2         5.966028        0.320247           5.966028           0.320247
# 3        12.340657       -0.969676          12.340657           0.127593
# 4         9.226852       -0.794907           9.226852           0.087515
# ..             ...             ...                ...                ...
# 93       12.544106       -0.597086          12.544106           0.085364
# 94       13.600454       -4.868966          13.600454           0.001785
# 95       10.518101       -0.638452          10.518101           0.099259
# 96       12.949494       -1.256091          12.949494           0.031563
# 97       12.184662       -0.286992          12.184662           0.011894
#
#          qed    MolWt  ...  SAamideO      PSA  #NandO  RuleOfFive  \
# 0   0.266085  415.424  ...    30.067  214.693    11.0         1.0
# 1   0.673727  171.240  ...     0.000   71.774     3.0         0.0
# 2   0.824007  274.795  ...     0.000   16.135     2.0         0.0
# 3   0.505505  346.339  ...     0.000  111.835     8.0         0.0
# 4   0.472427  169.180  ...     0.000   92.371     4.0         0.0
# ..       ...      ...  ...       ...      ...     ...         ...
# 93  0.671999  404.547  ...     0.000   84.800     5.0         0.0
# 94  0.732809  315.678  ...     0.000   51.230     3.0         0.0
# 95  0.623852  157.213  ...     0.000   75.498     3.0         0.0
# 96  0.139865  791.115  ...     0.000  201.339    11.0         3.0
# 97  0.571846  416.583  ...     0.000   97.763     4.0         0.0
#
#     RuleOfThree  #ringatoms  #in34  #in56  #noncon  #nonHatm
# 0           1.0         8.0    4.0    4.0      3.0      28.0
# 1           0.0         6.0    0.0    6.0      6.0      12.0
# 2           0.0        12.0    0.0   12.0      0.0      19.0
# 3           0.0        12.0    0.0   12.0      1.0      25.0
# 4           0.0         6.0    0.0    6.0      0.0      12.0
# ..          ...         ...    ...    ...      ...       ...
# 93          1.0        16.0    0.0   16.0     10.0      29.0
# 94          0.0        13.0    3.0   10.0      4.0      21.0
# 95          1.0         6.0    0.0    6.0      6.0      11.0
# 96          1.0         6.0    0.0    6.0      0.0      32.0
# 97          0.0        21.0    0.0   21.0     16.0      29.0
#
# [98 rows x 261 columns]

# %% [markdown]
# ## Data split and feature selection

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from ITMO_FS.embedded import MOS

# %%
X_train_val = data_train_val.drop(columns = [TARGET_COLUMN, 'smiles'])
X_test = data_test.drop(columns = [TARGET_COLUMN, 'smiles'])
y_train_val = data_train_val.active
y_test = data_test.active

# %%
scaler = MinMaxScaler()
scaler.fit(pd.concat([X_train_val, X_test]))
X_train_val = scaler.transform(X_train_val)
X_test = scaler.transform(X_test)

# %%
# mos = MOS()

# mos.fit(np.concatenate([X_train_val, X_test], axis=0), pd.concat([y_train_val, y_test]).to_numpy(), feature_names=data_train_val.columns)
# X_train_val = mos.transform(X_train_val)
# X_test = mos.transform(X_test)

# %%
X_train_val
# Out:
# array([[0.        , 0.        , 0.66301322, ..., 0.15      , 0.        ,
#         0.12820513],
#        [0.        , 0.        , 0.74540896, ..., 0.35      , 0.        ,
#         0.21794872],
#        [0.        , 0.        , 0.71192534, ..., 0.3       , 0.3030303 ,
#         0.74358974],
#        ...,
#        [0.        , 1.        , 0.767669  , ..., 0.4       , 0.12121212,
#         0.23076923],
#        [0.        , 1.        , 0.88693768, ..., 0.125     , 0.        ,
#         0.16666667],
#        [0.        , 1.        , 0.57863342, ..., 0.3       , 0.        ,
#         0.14102564]])

# %%
X_train_val.shape
# Out:
# (372, 259)

# %%
skf = StratifiedKFold(n_splits=4,  random_state=42, shuffle=True)

# %% [markdown]
# ## Models creating

# %%
def get_model(model):
    '''
    Get the model from six state-of-the-art machine learning models.
    '''
    if model=='svm':
        from sklearn.svm import SVC
        names = ["Linear SVM"]
        classifiers = [
        SVC()    
        ]
    elif model=='ab':
        from sklearn.ensemble import AdaBoostClassifier
        names = ["AdaBoost"]
        classifiers = [
        AdaBoostClassifier() 
        ]
    elif model=='knn':
        from sklearn.neighbors import KNeighborsClassifier
        names = ["K-Nearest Neighbors"]
        classifiers = [
        KNeighborsClassifier()
        ]
    elif model=='dt':
        from sklearn.tree import DecisionTreeClassifier
        names = ["Decision Tree"]
        classifiers = [
        DecisionTreeClassifier()   
        ]
    elif model=='nb':
        from sklearn.naive_bayes import GaussianNB
        names = ["Naive Bayes"]
        classifiers = [
         GaussianNB()   
        ]
    elif model=='rfc':
        from sklearn.ensemble import RandomForestClassifier
        names = ["Random Forest"]
        classifiers = [
        RandomForestClassifier()
        ]
    elif model=='xgboost':
        from xgboost import XGBClassifier
        names = ["XGBoost"]
        classifiers = [
        XGBClassifier()
        ]
    elif model=='mlpclassifier':
        from sklearn.neural_network import MLPClassifier
        names = ["MLPClassifier"]
        classifiers = [
        MLPClassifier()
        ]
    else:
        raise RuntimeError('Unknown classifier')
    
    return classifiers

# %% [markdown]
# ## Parameters list

# %%
parameters = {
              'svm': {'model__C': (1, 5, 10, 50, 100), 'model__probability': [True]}, 
              'ab': {'model__n_estimators': (10, 25, 50, 100, 125, 150, 200)}, 
              'knn': {'model__n_neighbors': (3, 5, 10, 50, 75, 100), 'model__leaf_size': (1, 2, 3, 5, 10, 15, 20), 
                      'model__weights': ['uniform', 'distance']}, 
              'dt': {'model__max_depth': (10, 25, 50, 100), 'model__min_samples_leaf': (1, 3, 5, 10)}, 
              'nb': {}, 
              'rfc': {'model__max_depth': (2, 3, 5, 7, 10), 'model__n_estimators': (50, 100, 150, 200),
                     'model__min_samples_leaf': (1, 3, 5, 10)},
              'mlpclassifier': {'model__hidden_layer_sizes': (
                                  (100, 60, 30, 10), 
                                  (150, 100, 50, 25, 10),
                                  (100, 50, 25, 10)),
                                'model__alpha': (0.0001, 0.001, 0.00001, 0.01), 
                                'model__learning_rate': ['constant', 'adaptive'],
                               },
              'xgboost': {'model__n_estimators': (10, 25, 50, 100)}
            }

# %% [markdown]
# ## Evaluating

# %%
from imblearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, f1_score, accuracy_score
from imblearn.over_sampling import SMOTE

# %%
best_clfs_encode = {}
for name, param in parameters.items():
    model = get_model(name)[0]

#     param['over__k_neighbors'] = (1, 3, 5, 10, 15, 20, 25)
#     over = SMOTE(sampling_strategy=1)
#     steps = [('over', over), ('model', model)]
    
    steps = [('model', model)]

    pipeline = Pipeline(steps=steps)
    clf = GridSearchCV(pipeline, param, scoring='roc_auc', cv=skf, n_jobs=-1)
    clf.fit(X_train_val, y_train_val)

    print(f'Best params for {name}:', clf.best_params_)
    pipe = clf.best_estimator_['model']

    print('Test ROC AUC for the best model %.2f' % roc_auc_score(y_test, pipe.predict_proba(X_test)[:,1]))
    print('Test accuracy for the best model %.2f' % accuracy_score(y_test, pipe.predict(X_test)))
    print('Test f1-score for the best model %.2f' % f1_score(y_test, pipe.predict(X_test)))
    print()
    best_clfs_encode[name] = clf.best_estimator_
# Out:
# Best params for svm: {'model__C': 50, 'model__probability': True}
# Test ROC AUC for the best model 0.85
# Test accuracy for the best model 0.82
# Test f1-score for the best model 0.89
#
# Best params for ab: {'model__n_estimators': 50}
# Test ROC AUC for the best model 0.92
# Test accuracy for the best model 0.85
# Test f1-score for the best model 0.90
#
# Best params for knn: {'model__leaf_size': 1, 'model__n_neighbors': 75, 'model__weights': 'distance'}
# Test ROC AUC for the best model 0.72
# Test accuracy for the best model 0.80
# Test f1-score for the best model 0.89
#
# Best params for dt: {'model__max_depth': 25, 'model__min_samples_leaf': 10}
# Test ROC AUC for the best model 0.89
# Test accuracy for the best model 0.81
# Test f1-score for the best model 0.88
#
# Best params for nb: {}
# Test ROC AUC for the best model 0.70
# Test accuracy for the best model 0.24
# Test f1-score for the best model 0.16
#
# Best params for rfc: {'model__max_depth': 10, 'model__min_samples_leaf': 10, 'model__n_estimators': 50}
# Test ROC AUC for the best model 0.92
# Test accuracy for the best model 0.87
# Test f1-score for the best model 0.92
#
# Best params for mlpclassifier: {'model__alpha': 0.0001, 'model__hidden_layer_sizes': (150, 100, 50, 25, 10), 'model__learning_rate': 'adaptive'}
# Test ROC AUC for the best model 0.82
# Test accuracy for the best model 0.85
# Test f1-score for the best model 0.91
#
# [15:21:37] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best params for xgboost: {'model__n_estimators': 50}
# Test ROC AUC for the best model 0.91
# Test accuracy for the best model 0.85
# Test f1-score for the best model 0.90
# /home/lizzka239/anaconda3/envs/rdkit/lib/python3.9/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/lizzka239/anaconda3/envs/rdkit/lib/python3.9/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# /home/lizzka239/anaconda3/envs/rdkit/lib/python3.9/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# /home/lizzka239/anaconda3/envs/rdkit/lib/python3.9/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
